# %%
from TSM_ABM import *

# %%
A = [usuario('A', a/100+0.05, a <= 30) for a in range(1,101)]
B = [usuario('B', b/100, b <= 30) for b in range(1,101)]
I = plataforma(15,15,10,10)
PA, PB = 10,10
e1, lp = update_prices_to_eq(I,A,B,PA,PB,False,True)

fig, ax = plt.subplots(figsize=(12,6))

e1.plot(ax=ax, color=['green','blue','red'], secondary_y=['Beneficio_I'], legend=True)
ax.set_ylim(0,100)
ax.set_xlabel('Iteracion')
ax.set_ylabel('Da;Db (N usuarios)')
ax.plot([lp,lp],[0,100],  color = 'grey', linestyle='--',label='Largo_plazo')
ax.right_ax.set_ylabel('Beneficio ($)')
ax.right_ax.set_ylim(0,2500)
ax.set_title(F"PA = {PA}; PB= {PB}");

# %%
A = [usuario('A', a/100+0.05, a <= 50) for a in range(1,101)]
B = [usuario('B', b/100, b <= 50) for b in range(1,101)]
I = plataforma(15,15,10,10)
PA, PB = 30,30
e1, lp = update_prices_to_eq(I,A,B,PA,PB,False,True)

fig, ax = plt.subplots(figsize=(12,6))

e1.plot(ax=ax, color=['green','blue','red'], secondary_y=['Beneficio_I'], legend=True)
ax.set_ylim(0,100)
ax.set_xlabel('Iteracion')
ax.set_ylabel('Da;Db (N usuarios)')
ax.plot([lp,lp],[0,100],  color = 'grey', linestyle='--',label='Largo_plazo')
ax.right_ax.set_ylabel('Beneficio ($)')
ax.right_ax.set_ylim(0,2500)
ax.set_title(F"PA = {PA}; PB= {PB}");

# %%
A = [usuario('A', a/100+0.05, a <= 50 )for a in range(1,101)]
B = [usuario('B', b/100, b <= 50) for b in range(1,101)]
I = plataforma(15,15,10,10)
PA, PB = 20,20
e1, lp = update_prices_to_eq(I,A,B,PA,PB,False,True)

fig, ax = plt.subplots(figsize=(12,6))

e1.plot(ax=ax, color=['green','blue','red'], secondary_y=['Beneficio_I'], legend=True)
ax.set_ylim(0,100)
ax.set_xlabel('Iteracion')
ax.set_ylabel('Da;Db (N usuarios)')
ax.plot([lp,lp],[0,100],  color = 'grey', linestyle='--',label='Largo_plazo')
ax.right_ax.set_ylabel('Beneficio ($)')
ax.right_ax.set_ylim(0,2500)
ax.set_title(F"PA = {PA}; PB= {PB}");

# %%
A = [usuario('A', a/100+0.05, a <= 50) for a in range(1,101)]
B = [usuario('B', b/100, b <= 50) for b in range(1,101)]
I = plataforma(15,15,10,10)
PA, PB = 30,20
e1, lp = update_prices_to_eq(I,A,B,PA,PB,False,True)

fig, ax = plt.subplots(figsize=(12,6))

e1.plot(ax=ax, color=['green','blue','red'], secondary_y=['Beneficio_I'], legend=True)
ax.set_ylim(0,100)
ax.set_xlabel('Iteracion')
ax.set_ylabel('Da;Db (N usuarios)')
ax.plot([lp,lp],[0,100],  color = 'grey', linestyle='--',label='Largo_plazo')
ax.right_ax.set_ylabel('Beneficio ($)')
ax.right_ax.set_ylim(0,2500)
ax.set_title(F"PA = {PA}; PB= {PB}");

# %%
A = [usuario('A', a/100+0.05, a <= 30) for a in range(1,101)]
B = [usuario('B', b/100, b <= 30) for b in range(1,101)]
I = plataforma(15,15,10,10)
PA, PB = 15,15
e1, lp = update_prices_to_eq(I,A,B,PA,PB,False,True)

fig, ax = plt.subplots(figsize=(12,6))

e1.plot(ax=ax, color=['green','blue','red'], secondary_y=['Beneficio_I'], legend=True)
ax.set_ylim(0,100)
ax.set_xlabel('Iteracion')
ax.set_ylabel('Da;Db (N usuarios)')
ax.plot([lp,lp],[0,100],  color = 'grey', linestyle='--',label='Largo_plazo')
ax.right_ax.set_ylabel('Beneficio ($)')
ax.right_ax.set_ylim(0,2500)
ax.set_title(F"PA = {PA}; PB= {PB}");

# %%
A = [usuario('A', a/100+0.05, a < 30) for a in range(1,101)]
B = [usuario('B', b/100, b < 30) for b in range(1,101)]
I = plataforma(100,100,10,10)

# %%
update_prices_to_eq(I,A,B,PA,PB,True,False,50)
# Out:
# It Da Db
# 0 29 29
# 1 37 32
# 2 43 38
# 3 53 48
# 4 64 59
# 5 72 67
# 6 76 71
# 7 77 72
# 8 78 73

# %%
historico.BENEFICIO.max()
# Out:
# 2110

# %%
historico[historico.BENEFICIO==historico.BENEFICIO.max()]
# Out:
#      PA  PB  DA  DB  BENEFICIO
# 771  29  21  62  67       1915

# %%
A = [usuario('A', a/100+0.05, a <= 50) for a in range(1,101)]
B = [usuario('B', b/100, b <= 50) for b in range(1,101)]
I = plataforma(10,10,10,10)
historico = update_prices_to_max(A,B,I, range(10,50), range(10,50), graph=True, IT_max = 50)
