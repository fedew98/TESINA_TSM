# %%
from CLASES import *

# %%
A = [usuario('A', a/100+0.05, a < 51) for a in range(1,101)]
B = [usuario('B', b/100, b < 51) for b in range(1,101)]
I = plataforma(15,15,10,10)
update_prices_to_eq(I,A,B,20,15,True)
# Out:
# It Da Db
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5d3ba7154920> in <module>
#       2 B = [usuario('B', b/100, b < 51) for b in range(1,101)]
#       3 I = plataforma(15,15,10,10)
# ----> 4 update_prices_to_eq(I,A,B,20,15,True)
#
# ~\OneDrive - Facultad de Ciencias Económicas - Universidad de Buenos Aires\FCE\SEMINARIO\TESIS\TSM_MONOPOLY_CLASSES.py in update_prices_to_eq(A, B, PA, PB, print_result, IT_max)
#      61         print('It','Da','Db')
#      62     for it in range(IT_max):
# ---> 63         Da = np.sum([a.join for a in A])
#      64         Db = np.sum([b.join for b in B])
#      65
#
# TypeError: 'plataforma' object is not iterable

# %%
A = [usuario('A', a/100, a < 40) for a in range(1,101)]
B = [usuario('B', b/100, b < 40) for b in range(1,101)]
I = plataforma(20,20,10,10)
historico = update_prices_to_max(A,B,I, 8, 42,1, 8, 42, 1, graph=True, IT_max = 50)

# %%
historico.BENEFICIO.plot()

# %%
A = [usuario('A', a/100+0.01, a < 51) for a in range(1,101)]
B = [usuario('B', b/100, b < 51) for b in range(1,101)]
I = plataforma(15,15,10,10)
update_prices_to_eq(A,B,15,15,True)
# Out:
# It Da Db
# 0 50 50
# 1 72 71
# 2 80 79
# 3 83 82

# %%
I.PB
# Out:
# 5
